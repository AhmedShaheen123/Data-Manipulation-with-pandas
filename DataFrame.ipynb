# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing & Inspecting Data

# %%
homeles = pd.read_csv('homelessness.csv')

# %%
homeles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
homeles.describe()
# Out:
#        Unnamed: 0    individuals  family_members     state_pop
# count   51.000000      51.000000       51.000000  5.100000e+01
# mean    25.000000    7225.784314     3504.882353  6.405637e+06
# std     14.866069   15991.025083     7805.411811  7.327258e+06
# min      0.000000     434.000000       75.000000  5.776010e+05
# 25%     12.500000    1446.500000      592.000000  1.777414e+06
# 50%     25.000000    3082.000000     1482.000000  4.461153e+06
# 75%     37.500000    6781.500000     3196.000000  7.340946e+06
# max     50.000000  109008.000000    52070.000000  3.946159e+07

# %%
homeles.values
# Out:
# array([[0, 'East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        [1, 'Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        [2, 'Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        [3, 'West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        [4, 'Pacific', 'California', 109008.0, 20964.0, 39461588],
#        [5, 'Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        [6, 'New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        [7, 'South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        [8, 'South Atlantic', 'District of Columbia', 3770.0, 3134.0,
#         701547],
#        [9, 'South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        [10, 'South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        [11, 'Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        [12, 'Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        [13, 'East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
# ...

# %%
homeles.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
homeles.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
homeles.shape
# Out:
# (51, 6)

# %% [markdown]
# # Processing

# %%
homeles.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
is_in_Pacific = homeles['region'] == 'Pacific'

# %%
is_in_California = homeles['state'] == 'California'

# %%
homeles[is_in_Pacific&is_in_California]
# Out:
#    Unnamed: 0   region       state  individuals  family_members  state_pop
# 4           4  Pacific  California     109008.0         20964.0   39461588

# %%
#we can do the code before in the same place by add parentheses around each condition

# %%
is_it_in = homeles['state'].isin (['California','Alaska'])
homeles[is_it_in]
# Out:
#    Unnamed: 0   region       state  individuals  family_members  state_pop
# 1           1  Pacific      Alaska       1434.0           582.0     735139
# 4           4  Pacific  California     109008.0         20964.0   39461588

# %% [markdown]
# # sorting values

# %%
#sorting values can be by selecting which cloumn we need to be assending by the next way of give it all the same condition by the next of next 
homeles.sort_values(['individuals','state'],ascending=[True,True])
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 34          34  West North Central          North Dakota        467.0
# 7            7      South Atlantic              Delaware        708.0
# 39          39         New England          Rhode Island        747.0
# 45          45         New England               Vermont        780.0
# 29          29         New England         New Hampshire        835.0
# 41          41  West North Central          South Dakota        836.0
# 26          26            Mountain               Montana        983.0
# 48          48      South Atlantic         West Virginia       1021.0
# 24          24  East South Central           Mississippi       1024.0
# 12          12            Mountain                 Idaho       1297.0
# 1            1             Pacific                Alaska       1434.0
# ...

# %%
homeles.sort_values(['individuals','state'],ascending=True)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 34          34  West North Central          North Dakota        467.0
# 7            7      South Atlantic              Delaware        708.0
# 39          39         New England          Rhode Island        747.0
# 45          45         New England               Vermont        780.0
# 29          29         New England         New Hampshire        835.0
# 41          41  West North Central          South Dakota        836.0
# 26          26            Mountain               Montana        983.0
# 48          48      South Atlantic         West Virginia       1021.0
# 24          24  East South Central           Mississippi       1024.0
# 12          12            Mountain                 Idaho       1297.0
# 1            1             Pacific                Alaska       1434.0
# ...

# %%
# We can write the condioton in the betwen brackts like that
#that can be do with the date also 
homeles[homeles['individuals']>5000]
# Out:
#     Unnamed: 0              region           state  individuals  \
# 2            2            Mountain         Arizona       7259.0
# 4            4             Pacific      California     109008.0
# 5            5            Mountain        Colorado       7607.0
# 9            9      South Atlantic         Florida      21443.0
# 10          10      South Atlantic         Georgia       6943.0
# 13          13  East North Central        Illinois       6752.0
# 21          21         New England   Massachusetts       6811.0
# 22          22  East North Central        Michigan       5209.0
# 28          28            Mountain          Nevada       7058.0
# 30          30        Mid-Atlantic      New Jersey       6048.0
# 32          32        Mid-Atlantic        New York      39827.0
# 33          33      South Atlantic  North Carolina       6451.0
# 35          35  East North Central            Ohio       6929.0
# 37          37             Pacific          Oregon      11139.0
# ...

# %%
canu = [ "South Atlantic" , "Mid-Atlantic"]
homeles[homeles["region"].isin(canu)]
# Out:
#     Unnamed: 0          region                 state  individuals  \
# 7            7  South Atlantic              Delaware        708.0
# 8            8  South Atlantic  District of Columbia       3770.0
# 9            9  South Atlantic               Florida      21443.0
# 10          10  South Atlantic               Georgia       6943.0
# 20          20  South Atlantic              Maryland       4914.0
# 30          30    Mid-Atlantic            New Jersey       6048.0
# 32          32    Mid-Atlantic              New York      39827.0
# 33          33  South Atlantic        North Carolina       6451.0
# 38          38    Mid-Atlantic          Pennsylvania       8163.0
# 40          40  South Atlantic        South Carolina       3082.0
# 46          46  South Atlantic              Virginia       3928.0
# 48          48  South Atlantic         West Virginia       1021.0
#
#     family_members  state_pop
# 7            374.0     965479
# 8           3134.0     701547
# ...

# %% [markdown]
# # Summary statistcs

# %%
import os 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'avoplotto.pkl',
#  'DataFrame.ipynb',
#  'homelessness.csv',
#  'sales_subset.csv',
#  'temperatures.csv']

# %%
def pct30(column):
    return column.quantile(0.3)

# %%
sales = pd.read_csv('sales_subset.csv')
sales.shape
# Out:
# (10774, 10)

# %%
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10774 non-null  int64
#  1   store                 10774 non-null  int64
#  2   type                  10774 non-null  object
#  3   department            10774 non-null  int64
#  4   date                  10774 non-null  object
#  5   weekly_sales          10774 non-null  float64
#  6   is_holiday            10774 non-null  bool
#  7   temperature_c         10774 non-null  float64
#  8   fuel_price_usd_per_l  10774 non-null  float64
#  9   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(3), object(2)
# memory usage: 768.2+ KB

# %%
sales.describe()
# Out:
#          Unnamed: 0         store    department   weekly_sales  temperature_c  \
# count  10774.000000  10774.000000  10774.000000   10774.000000   10774.000000
# mean    5386.500000     15.441897     45.218118   23843.950149      15.731978
# std     3110.330234     11.534511     29.867779   30220.387557       9.922446
# min        0.000000      1.000000      1.000000   -1098.000000      -8.366667
# 25%     2693.250000      4.000000     20.000000    3867.115000       7.583333
# 50%     5386.500000     13.000000     40.000000   12049.065000      16.966667
# 75%     8079.750000     20.000000     72.000000   32349.850000      24.166667
# max    10773.000000     39.000000     99.000000  293966.050000      33.827778
#
#        fuel_price_usd_per_l  unemployment
# count          10774.000000  10774.000000
# mean               0.749746      8.082009
# std                0.059494      0.624355
# min                0.664129      3.879000
# 25%                0.708246      7.795000
# ...

# %%
sales.median()
# Out:
# C:\Users\Shaheeen\AppData\Local\Temp/ipykernel_7700/3879698735.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.median()
# Unnamed: 0               5386.500000
# store                      13.000000
# department                 40.000000
# weekly_sales            12049.065000
# is_holiday                  0.000000
# temperature_c              16.966667
# fuel_price_usd_per_l        0.743381
# unemployment                8.099000
# dtype: float64

# %%
#agg  aplly summery statistic of many column data 
sales[['weekly_sales','temperature_c']].agg(pct30)
# Out:
# weekly_sales     5128.481000
# temperature_c       8.766667
# dtype: float64

# %%
#we will aplly function start by cum that aplly the code to the row and the previous rows
sales['temperature_c'].cummax()
# Out:
# 0         5.727778
# 1         8.055556
# 2        16.816667
# 3        22.527778
# 4        27.050000
#            ...
# 10769    33.827778
# 10770    33.827778
# 10771    33.827778
# 10772    33.827778
# 10773    33.827778
# Name: temperature_c, Length: 10774, dtype: float64

# %%
sales['temperature_c'].cumsum()
# Out:
# 0             5.727778
# 1            13.783333
# 2            30.600000
# 3            53.127778
# 4            80.177778
#              ...
# 10769    169405.211111
# 10770    169421.150000
# 10771    169448.438889
# 10772    169474.083333
# 10773    169496.333333
# Name: temperature_c, Length: 10774, dtype: float64

# %%
sales['department'].value_counts()
# Out:
# 1     144
# 55    144
# 71    144
# 67    144
# 60    144
#      ...
# 50     72
# 78     56
# 77     39
# 39      7
# 43      2
# Name: department, Length: 80, dtype: int64

# %%
# Print the head of the sales DataFrame
print(sales.head())

# Print the info about the sales DataFrame
print(sales.info())

# Print the mean of weekly_sales
print(sales['weekly_sales'].mean())

# Print the median of weekly_sales
print(sales['weekly_sales'].median())
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %%
# Print the maximum of the date column
print(sales['date'].max())
# Print the minimum of the date column
print(sales['date'].min())
# Out:
# 2012-10-26
# 2010-02-05

# %%
# Import NumPy and create custom IQR function
import numpy as np
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

# Update to print IQR and median of temperature_c, fuel_price_usd_per_l, & unemployment
print(sales[["temperature_c", "fuel_price_usd_per_l", "unemployment"]].agg([iqr,np.median]))
# Out:
#         temperature_c  fuel_price_usd_per_l  unemployment
# iqr         16.583333              0.073176         0.565
# median      16.966667              0.743381         8.099

# %%
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
store_types = sales.drop_duplicates(subset=['store','type'])
store_types.head()
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 0              0      1    A           1  2010-02-05      24924.50
# 901          901      2    A           1  2010-02-05      35034.06
# 1798        1798      4    A           1  2010-02-05      38724.42
# 2699        2699      6    A           1  2010-02-05      25619.00
# 3593        3593     10    B           1  2010-02-05      40212.84
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0          False       5.727778              0.679451         8.106
# 901        False       4.550000              0.679451         8.324
# 1798       False       6.533333              0.686319         8.623
# 2699       False       4.683333              0.679451         7.259
# 3593       False      12.411111              0.782478         9.765

# %%
# Drop duplicate store/type combinations
store_types = sales.drop_duplicates(subset=['store','type'])
print(store_types.head())
print('======================')
# Drop duplicate store/department combinations
store_depts = sales.drop_duplicates(subset=['store','department'])
print(store_depts.head())
print('======================')
# Subset the rows where is_holiday is True and drop duplicate dates
holiday_dates = sales[sales['is_holiday']].drop_duplicates(subset='date')
print('==============================')
# Print date col of holiday_dates
print(holiday_dates['date'])
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 0              0      1    A           1  2010-02-05      24924.50
# 901          901      2    A           1  2010-02-05      35034.06
# 1798        1798      4    A           1  2010-02-05      38724.42
# 2699        2699      6    A           1  2010-02-05      25619.00
# 3593        3593     10    B           1  2010-02-05      40212.84
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0          False       5.727778              0.679451         8.106
# 901        False       4.550000              0.679451         8.324
# 1798       False       6.533333              0.686319         8.623
# 2699       False       4.683333              0.679451         7.259
# 3593       False      12.411111              0.782478         9.765
# ...
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# ...

# %%
# Count the number of stores of each type
store_counts = sales['type'].value_counts()
print(store_counts)
print('======================')
# Get the proportion of stores of each type
store_props = sales['type'].value_counts(normalize=True)
print(store_props)
print('======================')
# Count the number of each department number and sort
dept_counts_sorted = sales['department'].value_counts(sort=True)
print(dept_counts_sorted)
print('======================')
# Get the proportion of departments of each number and sort
dept_props_sorted = sales['department'].value_counts(sort=True, normalize=True)
print(dept_props_sorted)
# Out:
# A    9872
# B     902
# Name: type, dtype: int64
# ...
# A    0.91628
# B    0.08372
# Name: type, dtype: float64
# ...
# 1     144
# 55    144
# 71    144
# 67    144
# 60    144
#      ...
# 50     72
# 78     56
# 77     39
# 39      7
# 43      2
# Name: department, Length: 80, dtype: int64
# ...
# 1     0.013366
# 55    0.013366
# 71    0.013366
# 67    0.013366
# 60    0.013366
#         ...
# 50    0.006683
# 78    0.005198
# 77    0.003620
# 39    0.000650
# 43    0.000186
# Name: department, Length: 80, dtype: float64

# %%
sales.groupby('store')['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum,np.median,np.mean])
# Out:
# C:\Users\Shaheeen\AppData\Local\Temp/ipykernel_7700/3980230741.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales.groupby('store')['weekly_sales','fuel_price_usd_per_l'].agg([min,max,sum,np.median,np.mean])
#       weekly_sales                                                   \
#                min        max          sum     median          mean
# store
# 1           -698.0  140504.41  18828144.55   9775.170  20896.941787
# 2          -1098.0  178982.89  23786139.34  13764.940  26517.435162
# 4            -88.0  165765.50  23540414.45  13063.930  26126.986071
# 6           -698.0  119812.38  19275700.71  13200.780  21561.186477
# 10          -798.0  232558.51  23178403.89  13336.080  25696.678370
# 13           -98.0  166872.27  23431368.47  13050.060  25664.149474
# 14          -498.0  293966.05  26889842.67  14792.990  30384.003017
# ...

# %%
sales['store'].unique()
# Out:
# array([ 1,  2,  4,  6, 10, 13, 14, 19, 20, 27, 31, 39], dtype=int64)

# %%
unemp_fuel_stats = sales.groupby("type")[["unemployment", "fuel_price_usd_per_l"]].agg([np.min, np.max, np.mean, np.median])

# %%
print(unemp_fuel_stats)
# Out:
#      unemployment                         fuel_price_usd_per_l            \
#              amin   amax      mean median                 amin      amax
# type
# A           3.879  8.992  7.972611  8.067             0.664129  1.107410
# B           7.170  9.765  9.279323  9.199             0.760023  1.107674
#
#
#           mean    median
# type
# A     0.744619  0.735455
# B     0.805858  0.803348

# %%
# Calc total weekly sales
sales_all = sales["weekly_sales"].sum()

# Subset for type A stores, calc total weekly sales
sales_A = sales[sales["type"] == "A"]["weekly_sales"].sum()

# Subset for type B stores, calc total weekly sales
sales_B = sales[sales["type"] == "B"]["weekly_sales"].sum()

# Subset for type C stores, calc total weekly sales
sales_C = sales[sales["type"] == "C"]["weekly_sales"].sum()

# Get proportion for each type
sales_propn_by_type = [sales_A, sales_B, sales_C] / sales_all
print(sales_propn_by_type)
# Out:
# [0.9097747 0.0902253 0.       ]

# %%
# Group by type; calc total weekly sales
sales_by_type = sales.groupby("type")["weekly_sales"].sum()

# Get proportion for each type
sales_propn_by_type = sales_by_type / sum(sales_by_type)
print(sales_propn_by_type)
# Out:
# type
# A    0.909775
# B    0.090225
# Name: weekly_sales, dtype: float64

# %%
# Import numpy with the alias np
import numpy as np

# For each store type, aggregate weekly_sales: get min, max, mean, and median
sales_stats = sales.groupby("type")["weekly_sales"].agg([np.min, np.max, np.mean, np.median])

# Print sales_stats
print(sales_stats)

# For each store type, aggregate unemployment and fuel_price_usd_per_l: get min, max, mean, and median
unemp_fuel_stats = sales.groupby("type")[["unemployment", "fuel_price_usd_per_l"]].agg([np.min, np.max, np.mean, np.median])

# Print unemp_fuel_stats
print(unemp_fuel_stats)
# Out:
#         amin       amax          mean    median
# type
# A    -1098.0  293966.05  23674.667242  11943.92
# B     -798.0  232558.51  25696.678370  13336.08
#      unemployment                         fuel_price_usd_per_l            \
#              amin   amax      mean median                 amin      amax
# type
# A           3.879  8.992  7.972611  8.067             0.664129  1.107410
# B           7.170  9.765  9.279323  9.199             0.760023  1.107674
#
#
#           mean    median
# type
# A     0.744619  0.735455
# B     0.805858  0.803348

# %% [markdown]
# # Pivot Table

# %%
sales.pivot_table(values='weekly_sales',index=['type'],aggfunc=[np.min,np.mea])
# Out:
# department            1              2             3             4   \
# type
# A           30961.725379   67600.158788  17160.002955  44285.399091
# B           44050.626667  112958.526667  30580.655000  51219.654167
#
# department            5             6             7             8   \
# type
# A           34821.011364   7136.292652  38454.336818  48583.475303
# B           63236.875000  10717.297500  52909.653333  90733.753333
#
# department            9             10  ...            90            91  \
# type                                    ...
# A           30120.449924  30930.456364  ...  85776.905909  70423.165227
# B           66679.301667  48595.126667  ...  14780.210000  13199.602500
#
# department             92            93            94             95  \
# type
# A           139722.204773  53413.633939  60081.155303  123933.787121
# B            50859.278333   1466.274167    161.445833   77082.102500
#
# ...

# %%
# Print mean weekly_sales by department and type; fill missing values with 0
print(sales.pivot_table(values="weekly_sales", index="department", columns="type", fill_value=0))
# Out:
# type                    A              B
# department
# 1            30961.725379   44050.626667
# 2            67600.158788  112958.526667
# 3            17160.002955   30580.655000
# 4            44285.399091   51219.654167
# 5            34821.011364   63236.875000
# ...                   ...            ...
# 95          123933.787121   77082.102500
# 96           21367.042857    9528.538333
# 97           28471.266970    5828.873333
# 98           12875.423182     217.428333
# 99             379.123659       0.000000
#
# [80 rows x 2 columns]

# %%
# Print the mean weekly_sales by department and type; fill missing values with 0s; sum all rows and cols
print(sales.pivot_table(values="weekly_sales", index="department", columns="type", fill_value=0, margins=True))
# Out:
# type                   A              B           All
# department
# 1           30961.725379   44050.626667  32052.467153
# 2           67600.158788  112958.526667  71380.022778
# 3           17160.002955   30580.655000  18278.390625
# 4           44285.399091   51219.654167  44863.253681
# 5           34821.011364   63236.875000  37189.000000
# ...                  ...            ...           ...
# 96          21367.042857    9528.538333  20337.607681
# 97          28471.266970    5828.873333  26584.400833
# 98          12875.423182     217.428333  11820.590278
# 99            379.123659       0.000000    379.123659
# All         23674.667242   25696.678370  23843.950149
#
# [81 rows x 3 columns]
